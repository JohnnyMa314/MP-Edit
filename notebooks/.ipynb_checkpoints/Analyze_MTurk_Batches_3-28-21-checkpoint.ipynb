# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import random

#results = pd.read_csv('../results/Batch_4386648_batch_results_3-29-21.csv')
results = pd.read_csv('../results/Batch_4425246_batch_results_5-3-21.csv')

# %%
from collections import Counter
Counter(results['WorkerId']).most_common(100)
# Out:
# [('A1W7I6FN183I8F', 100),
#  ('A2615YW1YERQBO', 92),
#  ('A270HX8LH9LJ8W', 86),
#  ('A1PAY3X73PQ16S', 73),
#  ('A2E0LU8V4EUX5C', 58)]

# %%
IO_cols = results.columns[['Input' in col or 'Answer' in col for col in results.columns]]
IO_cols = IO_cols.append(pd.Index(['WorkerId','WorkTimeInSeconds']))

df = results[IO_cols]
df
# Out:
#      Input.premID_1 Input.mask-type_1  Input.hypoID_1  \
# 0             12000     content-words           62087
# 1             12000     content-words           62087
# 2             10692     content-words           55028
# 3             10692     content-words           55028
# 4             12404     content-words           64002
# ..              ...               ...             ...
# 404           16648          gradient           48710
# 405           16648          gradient           48710
# 406            6842          gradient           19045
# 407            6842          gradient           19045
# 408            6842          gradient           19045
#
#                                        Input.premise_1  \
# 0     You may want to visit some of the other inlan...
# 1     You may want to visit some of the other inlan...
# 2    And when he did five to seven copypastes, whic...
# 3    And when he did five to seven copypastes, whic...
# 4    do you know who the guy was that was playing t...
# ..                                                 ...
# 404  Surrealism, a style he borrowed from Max Ernst...
# 405  Surrealism, a style he borrowed from Max Ernst...
# 406  DU has a law- student body of about 1,000, and...
# 407  DU has a law- student body of about 1,000, and...
# 408  DU has a law- student body of about 1,000, and...
#
#                                     Input.hypothesis_1  Input.orig-prob_1  \
# 0    Sant Joan is the name of a large inland hamlet...               1.00
# 1    Sant Joan is the name of a large inland hamlet...               1.00
# 2    When he did five to seven copy edits, he felt ...               1.00
# 3    When he did five to seven copy edits, he felt ...               1.00
# 4    Do you know who played the guy driving the red...               1.00
# ..                                                 ...                ...
# 404  His psyche had many negative things inside, so...               0.92
# 405  His psyche had many negative things inside, so...               0.92
# 406  DU has around 15000 students total compared to...               0.92
# 407  DU has around 15000 students total compared to...               0.92
# 408  DU has around 15000 students total compared to...               0.92
#
#     Input.model-label_1 Input.flip-class_1  Input.premID_2 Input.mask-type_2  \
# 0               neutral       Certain-Flip           12000     content-words
# 1               neutral       Certain-Flip           12000     content-words
# 2               neutral       Certain-Same           10692     content-words
# 3               neutral       Certain-Same           10692     content-words
# 4               neutral       Certain-Same           12404     content-words
# ..                  ...                ...             ...               ...
# 404          entailment       Certain-Same           16648          gradient
# 405          entailment       Certain-Same           16648          gradient
# 406       contradiction       Certain-Flip            6842          gradient
# 407       contradiction       Certain-Flip            6842          gradient
# 408       contradiction       Certain-Flip            6842          gradient
#
#      ...  Answer.comments Answer.numanswered Answer.response_1  \
# 0    ...               {}                  5           neutral
# 1    ...               {}                  5           neutral
# 2    ...               {}                  5           neutral
# 3    ...               {}                  5     contradiction
# 4    ...               {}                  5           neutral
# ..   ...              ...                ...               ...
# 404  ...               {}                  5        entailment
# 405  ...               {}                  5        entailment
# 406  ...               {}                  5     contradiction
# 407  ...               {}                  5           neutral
# 408  ...               {}                  5           neutral
#
#      Answer.response_2 Answer.response_3 Answer.response_4  Answer.response_5  \
# 0        contradiction     contradiction        entailment      contradiction
# 1        contradiction     contradiction        entailment      contradiction
# 2              neutral           neutral        entailment            neutral
# 3        contradiction        entailment        entailment            neutral
# 4              neutral           neutral           neutral      contradiction
# ..                 ...               ...               ...                ...
# 404            neutral        entailment           neutral            neutral
# 405            neutral        entailment           neutral         entailment
# 406      contradiction     contradiction     contradiction      contradiction
# 407            neutral           neutral           neutral            neutral
# 408            neutral           neutral           neutral            neutral
#
#                                       Answer.useragent        WorkerId  \
# 0    Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:8...  A2E0LU8V4EUX5C
# 1    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A270HX8LH9LJ8W
# 2    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A270HX8LH9LJ8W
# 3    Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:8...  A2E0LU8V4EUX5C
# 4    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A1W7I6FN183I8F
# ..                                                 ...             ...
# 404  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A2615YW1YERQBO
# 405  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A1W7I6FN183I8F
# 406  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A1W7I6FN183I8F
# 407  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A270HX8LH9LJ8W
# 408  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A2615YW1YERQBO
#
#     WorkTimeInSeconds
# 0                 147
# 1                 813
# 2                 589
# 3                  61
# 4                2101
# ..                ...
# 404                49
# 405               172
# 406               945
# 407               173
# 408              9672
#
# [409 rows x 50 columns]

# %%
ans_cols = df.columns[['Answer' in col for col in df.columns]]
df.loc[df['Input.hypoID_1'] == 0][ans_cols]
# Out:
# Empty DataFrame
# Columns: [Answer.comments, Answer.numanswered, Answer.response_1, Answer.response_2, Answer.response_3, Answer.response_4, Answer.response_5, Answer.useragent]
# Index: []

# %%
# reshape wide into long, premise_1, ... , premise_8 -> premise , ... , premise (len(8))
dt = pd.DataFrame()
for _ , row in df.iterrows():
    for i in range(1,6):
        n_cols = row.index[[str(i) in col for col in row.index]] # getting all prem_1, hypo_1, by integer
        n_cols = n_cols.append(pd.Index(['WorkTimeInSeconds', 'WorkerId']))
        one_row = row.loc[n_cols]
        one_row.index = pd.Index([col[:-2] for col in n_cols]) # removing the '_1', make generic
        dt = dt.append(one_row)

# %%
# rename columns and sort
s_df = dt.sort_values(by = ['Input.premID', 'Input.hypoID', 'Input.mask-type'])
new_cols = s_df.columns.values

# add in worker column 
renamed_cols = [col.split('.')[1] for col in new_cols[:-1] if len(col.split('.')) > 1]
renamed_cols.append('WorkTimeInSecon')
renamed_cols.append('Worker')
s_df.columns = renamed_cols

# %%
s_df.groupby('premID').count().sort_values(by='response')
# Out:
#          response  flip-class  hypoID  hypothesis  mask-type  model-label  \
# premID
# 12404.0         5           5       5           5          5            5
# 5495.0          5           5       5           5          5            5
# 6396.0          5           5       5           5          5            5
# 17454.0         5           5       5           5          5            5
# 17720.0         5           5       5           5          5            5
# ...           ...         ...     ...         ...        ...          ...
# 9803.0         15          15      15          15         15           15
# 8030.0         15          15      15          15         15           15
# 1125.0         25          25      25          25         25           25
# 20008.0        25          25      25          25         25           25
# 10692.0        35          35      35          35         35           35
#
#          orig-prob  premise  WorkTimeInSecon  Worker
# premID
# 12404.0          5        5                5       5
# 5495.0           5        5                5       5
# 6396.0           5        5                5       5
# 17454.0          5        5                5       5
# 17720.0          5        5                5       5
# ...            ...      ...              ...     ...
# 9803.0          15       15               15      15
# 8030.0          15       15               15      15
# 1125.0          25       25               25      25
# 20008.0         25       25               25      25
# 10692.0         35       35               35      35
#
# [145 rows x 10 columns]

# %%
np.median(s_df['WorkTimeInSecon'])/4/60
# Out:
# 1.5291666666666666

# %%
# Calcuating time per assignment for workers
sns.histplot(s_df['WorkTimeInSecon'])
plt.xlabel('Assignment Time (s)')
plt.xlim([0,4000])
plt.title('Time to Complete 5 Assignments (s), Avg: 1138s')
plt.savefig('../graphs/AssignmentTime.png', dpi=200)

# %%
# calculating bonuses for workers
bonus = s_df.loc[s_df['mask-type'] == 'original']
bonus['model-wrong'] = bonus['response'] != bonus['model-label']
bonus.groupby(['Worker']).agg({'model-wrong': ['sum', 'count']})
# Out:
# <ipython-input-116-f8fc85703785>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bonus['model-wrong'] = bonus['response'] != bonus['model-label']
#                model-wrong
#                        sum count
# Worker
# A1PAY3X73PQ16S          25    73
# A1W7I6FN183I8F          15   100
# A2615YW1YERQBO          22    92
# A270HX8LH9LJ8W          16    86
# A2E0LU8V4EUX5C          12    58

# %%
# getting majority votes and calculating the number of originals workers get correct.

# slicing out the originals
origs = s_df.loc[s_df['mask-type'] == 'original']

agrees = []
orig_df = pd.DataFrame()

for hypo_id in origs['hypoID'].unique():
    ex = origs.loc[origs['hypoID'] == hypo_id] # 
    agrees.append(len(Counter(ex.response)))
    if len(Counter(ex.response)) < 3: # selecting agreements only
        agree = ex.copy().iloc[0]
        agree.response = ex['response'].value_counts().idxmax()
        agree['maj_count'] = len(ex['response'])
        agree['lab_count'] = len(Counter(ex.response))
        agree['keep'] = len(ex['response']) == 2 and len(Counter(ex.response)) == 1
        orig_df = orig_df.append(agree)

orig_df = orig_df.loc[(orig_df['maj_count'] == 3) | (orig_df['keep'] == 1.0)]
orig_df['model-wrong'] = orig_df['response'] != orig_df['model-label']
orig_wrongs = orig_df.loc[orig_df['model-wrong'] == True]
orig_wrongs.to_csv('../mturk/4-15-21/results/original_wrongs_5-3-21.csv')

# %%
orig_df['model-wrong'].sum()/len(orig_df['model-wrong'])
# Out:
# 0.15789473684210525

# %%
Counter(orig_wrongs['response'])
# Out:
# Counter({'contradiction': 5, 'neutral': 14, 'entailment': 2})

# %%
len(orig_df['model-wrong'])
# Out:
# 133

# %%
# same as above but for entire dataset, getting generations that have majority labels
from collections import Counter

agrees = []
cum_df = pd.DataFrame()
sf_df = s_df.loc[s_df['mask-type'] != 'original']
for hypo_id in sf_df['hypoID'].unique():
    ex = sf_df.loc[sf_df['hypoID'] == hypo_id]
    agrees.append(len(Counter(ex.response)))
    if len(Counter(ex.response)) < 3:
        agree = ex.copy().iloc[0]
        agree.response = ex['response'].value_counts().idxmax()
        agree['maj_count'] = len(ex['response'])
        agree['lab_count'] = len(Counter(ex.response))
        agree['keep'] = len(ex['response']) == 2 and len(Counter(ex.response)) == 1
        cum_df = cum_df.append(agree)

cum_df = cum_df.loc[(cum_df['maj_count'] == 3) | cum_df['keep'] == 1.0]
print(Counter(cum_df['mask-type']))
cum_df
# Out:
# Counter({'content-words': 176, 'gradient': 172, 'data-slices': 170})
#      WorkTimeInSecon          Worker      flip-class   hypoID  \
# 30           18388.0  A1PAY3X73PQ16S  Uncertain-Flip     51.0
# 30           18388.0  A1PAY3X73PQ16S  Uncertain-Same     52.0
# 30           18388.0  A1PAY3X73PQ16S    Certain-Flip     53.0
# 64             823.0  A270HX8LH9LJ8W  Uncertain-Flip   2269.0
# 64             823.0  A270HX8LH9LJ8W  Uncertain-Same   2278.0
# ..               ...             ...             ...      ...
# 187             56.0  A2E0LU8V4EUX5C  Uncertain-Same  47116.0
# 226            162.0  A270HX8LH9LJ8W    Certain-Flip  47287.0
# 226            162.0  A270HX8LH9LJ8W  Uncertain-Same  47288.0
# 226            162.0  A270HX8LH9LJ8W  Uncertain-Flip  47290.0
# 226            162.0  A270HX8LH9LJ8W  Uncertain-Flip  47291.0
#
#                                             hypothesis  keep  lab_count  \
# 30    Would the job pay less if it were done by Tripp?   1.0        1.0
# 30   Would the job be better if it were not held by...   1.0        1.0
# 30   Would the job pay less if it were only held by...   1.0        1.0
# 64   The Malla period saw advancements in either th...   0.0        1.0
# 64   The Malla period also saw no advancements in e...   0.0        1.0
# ..                                                 ...   ...        ...
# 187  The researchers knew the names of most of the ...   0.0        2.0
# 226  The civilization of the Roman Empire tried to ...   0.0        2.0
# 226  The civilization of the Roman Empire was more ...   0.0        1.0
# 226  The civilization of the Roman Empire did not c...   0.0        1.0
# 226  The civilization of the Roman Empire did not c...   0.0        1.0
#
#      maj_count      mask-type    model-label  orig-prob   premID  \
# 30         2.0    data-slices  contradiction       0.99    131.0
# 30         2.0    data-slices     entailment       0.99    131.0
# 30         2.0    data-slices  contradiction       0.99    131.0
# 64         3.0  content-words        neutral       1.00    427.0
# 64         3.0  content-words  contradiction       1.00    427.0
# ..         ...            ...            ...        ...      ...
# 187        3.0    data-slices  contradiction       1.00  87090.0
# 226        3.0    data-slices  contradiction       0.99  87394.0
# 226        3.0    data-slices     entailment       0.99  87394.0
# 226        3.0    data-slices        neutral       0.99  87394.0
# 226        3.0    data-slices        neutral       0.99  87394.0
#
#                                                premise       response
# 30   If the job were held by someone other than Tri...        neutral
# 30   If the job were held by someone other than Tri...        neutral
# 30   If the job were held by someone other than Tri...        neutral
# 64   The Malla period saw completion of Nepal's mos...     entailment
# 64   The Malla period saw completion of Nepal's mos...  contradiction
# ..                                                 ...            ...
# 187  The names of the companies are confidential an...  contradiction
# 226  Tribal culture reigned, untouched by the more ...        neutral
# 226  Tribal culture reigned, untouched by the more ...     entailment
# 226  Tribal culture reigned, untouched by the more ...        neutral
# 226  Tribal culture reigned, untouched by the more ...        neutral
#
# [518 rows x 14 columns]

# %%
## Plotting Agreement between annotators
fig, ax = plt.subplots(figsize=(10,6))

plt.rcParams.update({'font.size': 15})
labels, counts = np.unique(agrees, return_counts=True)

plt.bar(labels, counts, align='center')
plt.gca().set_xticks(labels)
plt.xlabel('Number of Labels for Premise-Hypothesis Pair')
plt.ylabel('Count of Pairs')
plt.title('Agreement between Turkers for Premise-Hypo Pair')
plt.savefig('../graphs/Turker_Agreement.png', dpi = 200)
plt.show()

# %% [markdown]
# # Analysis of Success of Flip Classes in Generating Model != Annotator Labels

# %%
cum_df
# Out:
#      WorkTimeInSecon          Worker      flip-class   hypoID  \
# 30           18388.0  A1PAY3X73PQ16S  Uncertain-Flip     51.0
# 30           18388.0  A1PAY3X73PQ16S  Uncertain-Same     52.0
# 30           18388.0  A1PAY3X73PQ16S    Certain-Flip     53.0
# 64             823.0  A270HX8LH9LJ8W  Uncertain-Flip   2269.0
# 64             823.0  A270HX8LH9LJ8W  Uncertain-Same   2278.0
# ..               ...             ...             ...      ...
# 187             56.0  A2E0LU8V4EUX5C  Uncertain-Same  47116.0
# 226            162.0  A270HX8LH9LJ8W    Certain-Flip  47287.0
# 226            162.0  A270HX8LH9LJ8W  Uncertain-Same  47288.0
# 226            162.0  A270HX8LH9LJ8W  Uncertain-Flip  47290.0
# 226            162.0  A270HX8LH9LJ8W  Uncertain-Flip  47291.0
#
#                                             hypothesis  keep  lab_count  \
# 30    Would the job pay less if it were done by Tripp?   1.0        1.0
# 30   Would the job be better if it were not held by...   1.0        1.0
# 30   Would the job pay less if it were only held by...   1.0        1.0
# 64   The Malla period saw advancements in either th...   0.0        1.0
# 64   The Malla period also saw no advancements in e...   0.0        1.0
# ..                                                 ...   ...        ...
# 187  The researchers knew the names of most of the ...   0.0        2.0
# 226  The civilization of the Roman Empire tried to ...   0.0        2.0
# 226  The civilization of the Roman Empire was more ...   0.0        1.0
# 226  The civilization of the Roman Empire did not c...   0.0        1.0
# 226  The civilization of the Roman Empire did not c...   0.0        1.0
#
#      maj_count      mask-type    model-label  orig-prob   premID  \
# 30         2.0    data-slices  contradiction       0.99    131.0
# 30         2.0    data-slices     entailment       0.99    131.0
# 30         2.0    data-slices  contradiction       0.99    131.0
# 64         3.0  content-words        neutral       1.00    427.0
# 64         3.0  content-words  contradiction       1.00    427.0
# ..         ...            ...            ...        ...      ...
# 187        3.0    data-slices  contradiction       1.00  87090.0
# 226        3.0    data-slices  contradiction       0.99  87394.0
# 226        3.0    data-slices     entailment       0.99  87394.0
# 226        3.0    data-slices        neutral       0.99  87394.0
# 226        3.0    data-slices        neutral       0.99  87394.0
#
#                                                premise       response
# 30   If the job were held by someone other than Tri...        neutral
# 30   If the job were held by someone other than Tri...        neutral
# 30   If the job were held by someone other than Tri...        neutral
# 64   The Malla period saw completion of Nepal's mos...     entailment
# 64   The Malla period saw completion of Nepal's mos...  contradiction
# ..                                                 ...            ...
# 187  The names of the companies are confidential an...  contradiction
# 226  Tribal culture reigned, untouched by the more ...        neutral
# 226  Tribal culture reigned, untouched by the more ...     entailment
# 226  Tribal culture reigned, untouched by the more ...        neutral
# 226  Tribal culture reigned, untouched by the more ...        neutral
#
# [518 rows x 14 columns]

# %%
orig_df_m = s_df.loc[s_df['mask-type'] == 'original'].drop_duplicates('premID')

# %%
cum_df.shape
# Out:
# (518, 14)

# %%
df_out.columns
# Out:
# Index(['WorkTimeInSecon', 'Worker', 'flip-class', 'hypoID', 'hypothesis_x',
#        'keep', 'lab_count', 'maj_count', 'mask-type', 'model-label_x',
#        'orig-prob', 'premID', 'premise', 'response', 'hypothesis_y',
#        'model-label_y'],
#       dtype='object')

# %%
df_out = pd.merge(cum_df, orig_df_m[['premID', 'hypothesis', 'model-label']], how='left', on ='premID')
assert df_out.shape[0] == cum_df.shape[0]
df_out['model-wrong'] = df_out['response'] != df_out['model-label_x']
df_out = df_out[['flip-class', 'premID', 'premise', 'hypoID', 'hypothesis_x', 'hypothesis_y',
                'lab_count', 'maj_count', 'mask-type', 'model-label_x', 'response', 'model-wrong', 'model-label_y']]
df_out.columns = ['flip-class', 'premID', 'premise', 'hypoID', 'hypothesis', 'orig-hypothesis',
                'lab_count', 'maj_count', 'mask-type', 'model-label', 'response', 'model-wrong', 'orig-label']
df_out.to_csv('../mturk/4-15-21/results/mturk_clean_data_5-3-21.csv')

# %%
cum_df = df_out
cum_df.loc[cum_df['model-wrong'] == True].to_csv('../mturk/4-15-21/results/mturk_wrongs_5-3-21.csv')

# generating model wrong statistics
cum_df.groupby(['mask-type', 'flip-class']).agg({'model-wrong': ['mean', 'count', 'sum']}).T
# Out:
# mask-type         content-words                                             \
# flip-class         Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model-wrong mean       0.315789         0.24       0.439394       0.575758
#             count     19.000000        25.00      66.000000      66.000000
#             sum        6.000000         6.00      29.000000      38.000000
#
# mask-type          data-slices                                             \
# flip-class        Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model-wrong mean      0.407407        0.125       0.472222       0.436364
#             count    27.000000       16.000      72.000000      55.000000
#             sum      11.000000        2.000      34.000000      24.000000
#
# mask-type             gradient
# flip-class        Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model-wrong mean      0.235294         0.04       0.483871       0.470588
#             count    17.000000        25.00      62.000000      68.000000
#             sum       4.000000         1.00      30.000000      32.000000

# %% [markdown]
# ## visualize direction of differences between model label and MTurker label

# %%
plt.clf()
df = cum_df
df['MTurk-label'] = df['response']
RTE_mat = pd.crosstab(index=df['model-label'], columns=[df['MTurk-label']])
RTE_mat

sns.set(font_scale=1) # change font size
ax = sns.heatmap(RTE_mat, annot=True, fmt = '0', square=1, cbar = False, linewidth=1., cmap="YlGnBu", cbar_kws={"orientation": "horizontal"})

plt.title('Label Flips in MTurk Batch, Majority Label')

plt.savefig('../graphs/Label_Flips_MTurk_Maj.png', dpi = 200)

# %%
Counter(df['MTurk-label'])
# Out:
# Counter({'entailment': 68, 'contradiction': 99, 'neutral': 185})

# %%
Counter(df['model-label'])
# Out:
# Counter({'neutral': 130, 'contradiction': 109, 'entailment': 113})

# %%
Counter(df.loc[df['flip-class'] == 'Uncertain-Same']['MTurk-label'])
# Out:
# Counter({'contradiction': 37, 'neutral': 71, 'entailment': 17})

# %%
df = s_df

df['MTurk-label'] = df['response']
RTE_mat = pd.crosstab(index=df['model-label'], columns=[df['MTurk-label']])
RTE_mat

sns.set(font_scale=1) # change font size
ax = sns.heatmap(RTE_mat, annot=True, fmt = '0', square=1, cbar = False, linewidth=1., cmap="YlGnBu", cbar_kws={"orientation": "horizontal"})

plt.title('Label Flips in MTurk Batch, No Majority')
plt.tight_layout()
plt.savefig('../graphs/Label_Flips_MTurk_All.png', dpi = 200)

# %%
cum_df['premID']
# Out:
# 0        427.0
# 0        427.0
# 0        427.0
# 0        427.0
# 188      479.0
#         ...
# 61     85671.0
# 61     85671.0
# 80     87394.0
# 80     87394.0
# 80     87394.0
# Name: premID, Length: 352, dtype: float64

# %%
pd.merge(orig_df, cum_df, on = 'premID').to_csv('temp.csv')
