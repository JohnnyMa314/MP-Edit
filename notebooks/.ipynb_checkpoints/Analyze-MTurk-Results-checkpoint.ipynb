# %% [markdown]
# ## Cleaning, Formatting, and Purifying MTurk Batch Results

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

results = pd.read_csv('../results/Batch_4352801_batch_results.csv')

# %%
results.columns
# Out:
# Index(['HITId', 'HITTypeId', 'Title', 'Description', 'Keywords', 'Reward',
#        'CreationTime', 'MaxAssignments', 'RequesterAnnotation',
#        'AssignmentDurationInSeconds', 'AutoApprovalDelayInSeconds',
#        'Expiration', 'NumberOfSimilarHITs', 'LifetimeInSeconds',
#        'AssignmentId', 'WorkerId', 'AssignmentStatus', 'AcceptTime',
#        'SubmitTime', 'AutoApprovalTime', 'ApprovalTime', 'RejectionTime',
#        'RequesterFeedback', 'WorkTimeInSeconds', 'LifetimeApprovalRate',
#        'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.0',
#        'Input.index', 'Input.premID_1', 'Input.mask-type1', 'Input.hypoID_1',
#        'Input.premise_1', 'Input.hypothesis_1', 'Input.premID_2',
#        'Input.mask-type2', 'Input.hypoID_2', 'Input.premise_2',
#        'Input.hypothesis_2', 'Input.premID_3', 'Input.mask-type3',
#        'Input.hypoID_3', 'Input.premise_3', 'Input.hypothesis_3',
#        'Input.premID_4', 'Input.mask-type4', 'Input.hypoID_4',
#        'Input.premise_4', 'Input.hypothesis_4', 'Input.premID_5',
#        'Input.mask-type5', 'Input.hypoID_5', 'Input.premise_5',
#        'Input.hypothesis_5', 'Input.premID_6', 'Input.mask-type6',
#        'Input.hypoID_6', 'Input.premise_6', 'Input.hypothesis_6',
#        'Input.premID_7', 'Input.mask-type7', 'Input.hypoID_7',
#        'Input.premise_7', 'Input.hypothesis_7', 'Input.premID_8',
#        'Input.mask-type8', 'Input.hypoID_8', 'Input.premise_8',
#        'Input.hypothesis_8', 'Answer.comments', 'Answer.numanswered',
#        'Answer.response_1', 'Answer.response_2', 'Answer.response_3',
#        'Answer.response_4', 'Answer.response_5', 'Answer.response_6',
#        'Answer.response_7', 'Answer.response_8', 'Answer.response_ex',
#        'Answer.useragent', 'Approve', 'Reject'],
#       dtype='object')

# %%
IO_cols = results.columns[['Input' in col or 'Answer' in col for col in results.columns]]
IO_cols = IO_cols.append(pd.Index(['WorkerId']))

df = results[IO_cols]
df
# Out:
#      Input.0  Input.index  Input.premID_1 Input.mask-type1  Input.hypoID_1  \
# 0          0            0            4096         gradient               0
# 1          0            0            4096         gradient               0
# 2          0            0            4096         gradient               0
# 3          1            0            4096    content-words               1
# 4          1            0            4096    content-words               1
# ..       ...          ...             ...              ...             ...
# 271       90            0           12242      data-slices             706
# 272       90            0           12242      data-slices             706
# 273       91            0           12242         original             707
# 274       91            0           12242         original             707
# 275       91            0           12242         original             707
#
#                                        Input.premise_1  \
# 0    He may have to send cables, or something like ...
# 1    He may have to send cables, or something like ...
# 2    He may have to send cables, or something like ...
# 3    He may have to send cables, or something like ...
# 4    He may have to send cables, or something like ...
# ..                                                 ...
# 271  Would the prisoner, in the hottest week of a h...
# 272  Would the prisoner, in the hottest week of a h...
# 273  Would the prisoner, in the hottest week of a h...
# 274  Would the prisoner, in the hottest week of a h...
# 275  Would the prisoner, in the hottest week of a h...
#
#                                     Input.hypothesis_1  Input.premID_2  \
# 0    There's no possibility that he will not have t...            4609
# 1    There's no possibility that he will not have t...            4609
# 2    There's no possibility that he will not have t...            4609
# 3    There's no guarantee that he will have to send...            4609
# 4    There's no guarantee that he will have to send...            4609
# ..                                                 ...             ...
# 271  Is it possible that the prisoner in such hot w...            9172
# 272  Is it possible that the prisoner in such hot w...            9172
# 273  Is it possible that the prisoner in such hot w...            9172
# 274  Is it possible that the prisoner in such hot w...            9172
# 275  Is it possible that the prisoner in such hot w...            9172
#
#     Input.mask-type2  Input.hypoID_2  ... Answer.response_2 Answer.response_3  \
# 0      content-words               5  ...        entailment           neutral
# 1      content-words               5  ...        entailment           neutral
# 2      content-words               5  ...           neutral           neutral
# 3        data-slices               6  ...     contradiction           neutral
# 4        data-slices               6  ...     contradiction           neutral
# ..               ...             ...  ...               ...               ...
# 271         original             711  ...           neutral        entailment
# 272         original             711  ...           neutral        entailment
# 273         gradient             708  ...           neutral           neutral
# 274         gradient             708  ...           neutral           neutral
# 275         gradient             708  ...           neutral     contradiction
#
#      Answer.response_4 Answer.response_5  Answer.response_6 Answer.response_7  \
# 0           entailment     contradiction         entailment     contradiction
# 1           entailment        entailment         entailment     contradiction
# 2           entailment     contradiction         entailment           neutral
# 3              neutral     contradiction            neutral     contradiction
# 4        contradiction           neutral         entailment           neutral
# ..                 ...               ...                ...               ...
# 271            neutral           neutral      contradiction           neutral
# 272            neutral           neutral         entailment           neutral
# 273         entailment        entailment            neutral        entailment
# 274         entailment        entailment            neutral           neutral
# 275         entailment           neutral      contradiction           neutral
#
#     Answer.response_8  Answer.response_ex  \
# 0          entailment          entailment
# 1          entailment          entailment
# 2             neutral          entailment
# 3             neutral          entailment
# 4             neutral          entailment
# ..                ...                 ...
# 271           neutral          entailment
# 272           neutral          entailment
# 273     contradiction          entailment
# 274           neutral          entailment
# 275           neutral          entailment
#
#                                       Answer.useragent        WorkerId
# 0    Mozilla/5.0 (Windows NT 6.3; Win64; x64) Apple...  A17LF7GCAFYMSL
# 1    Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...  A24NDC7JH9LEM1
# 2    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A1ZT30BGR3266K
# 3    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A2XJH3WC02RMXQ
# 4    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A1UEZ91H4LYXZF
# ..                                                 ...             ...
# 271  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A1L3937MY09J3I
# 272  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  A2YOVBJ9EXAI8W
# 273  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...  A2IG18D6M0GNUZ
# 274  Mozilla/5.0 (X11; CrOS x86_64 13421.99.0) Appl...  A1PTH9KTRO06EG
# 275  Mozilla/5.0 (Linux; Android 11; Pixel 3a) Appl...  A31681CCEVDIH3
#
# [276 rows x 55 columns]

# %%
df.shape
# Out:
# (276, 55)

# %%
# reshape wide into long, premise_1, ... , premise_8 -> premise , ... , premise (len(8))

dt = pd.DataFrame()
for _ , row in df.iterrows():
    for i in range(1,9):
        n_cols = row.index[[str(i) in col for col in row.index]] # getting all prem_1, hypo_1, by integer
        n_cols = n_cols.append(pd.Index(['WorkerId']))
        one_row = row.loc[n_cols]
        one_row.index = pd.Index([col[:-2] for col in n_cols]) # removing the '_1', make generic
        dt = dt.append(one_row)

# %%
# rename columns and sort
s_df = dt.sort_values(by = ['Input.premID', 'Input.hypoID', 'Input.mask-typ'])
new_cols = s_df.columns.values

# add in worker column 
renamed_cols = [col.split('.')[1] for col in new_cols[:-1]]
renamed_cols.append('Worker')
s_df.columns = renamed_cols

# %%
s_df
# Out:
#           response  hypoID                                         hypothesis  \
# 18      entailment    40.0  The french painters that were represented incl...
# 19   contradiction    40.0  The french painters that were represented incl...
# 20   contradiction    40.0  The french painters that were represented incl...
# 21         neutral    41.0  The french painters that were represented incl...
# 22         neutral    41.0  The french painters that were represented incl...
# ..             ...     ...                                                ...
# 115        neutral   290.0  They were able to keep all the services within...
# 116     entailment   290.0  They were able to keep all the services within...
# 117     entailment   291.0  They were able to have more services within th...
# 118     entailment   291.0  They were able to have more services within th...
# 119     entailment   291.0  They were able to have more services within th...
#
#           mask-typ   premID  \
# 18        gradient     34.0
# 19        gradient     34.0
# 20        gradient     34.0
# 21   content-words     34.0
# 22   content-words     34.0
# ..             ...      ...
# 115    data-slices  12990.0
# 116    data-slices  12990.0
# 117       original  12990.0
# 118       original  12990.0
# 119       original  12990.0
#
#                                                premise          Worker
# 18   French painters represented include Delacroix ...  A2YOVBJ9EXAI8W
# 19   French painters represented include Delacroix ...  A2JP9IKRHNLRPI
# 20   French painters represented include Delacroix ...  A2CS8ESKDX6EBA
# 21   French painters represented include Delacroix ...  A2XYDJS33I2341
# 22   French painters represented include Delacroix ...  A3LPZVG62RNVL8
# ..                                                 ...             ...
# 115  It also will allow the organization to house i...  A243X2Y9HP7630
# 116  It also will allow the organization to house i...  A1CX45M5UVAM9R
# 117  It also will allow the organization to house i...   A5BVUW06ZQ6D3
# 118  It also will allow the organization to house i...  A1PAY3X73PQ16S
# 119  It also will allow the organization to house i...  A2YOVBJ9EXAI8W
#
# [2208 rows x 7 columns]

# %%
s_df.groupby('premID').count().sort_values(by='response')
# Out:
#          response  hypoID  hypothesis  mask-typ  premise  Worker
# premID
# 2789.0         11      12          12        12       12      12
# 3379.0         11      12          12        12       12      12
# 10152.0        11      12          12        12       12      12
# 10563.0        11      12          12        12       12      12
# 10801.0        11      12          12        12       12      12
# ...           ...     ...         ...       ...      ...     ...
# 4216.0         12      12          12        12       12      12
# 4243.0         12      12          12        12       12      12
# 4346.0         12      12          12        12       12      12
# 6770.0         12      12          12        12       12      12
# 12990.0        12      12          12        12       12      12
#
# [184 rows x 6 columns]

# %% [markdown]
# ### remove by premise where there is incomplete data

# %%
missing_prems = []

for prem_id in s_df['premID'].unique():
    if len(s_df.loc[s_df['premID'] == prem_id]) < 12:
        missing_prems.append(prem_id)
        
clean_df = s_df[~s_df['premID'].isin(missing_prems)]

# %%
s_df['premID'].unique().shape
# Out:
# (184,)

# %%
clean_df['premID'].unique().shape
# Out:
# (184,)

# %% [markdown]
# ## remove annotators that are noisy

# %% [markdown]
# ### get gold label where annotators agree >2

# %%
len(clean_df['hypoID'].unique())
# Out:
# 736

# %%
from collections import Counter

agrees = []
cum_df = pd.DataFrame()
for hypo_id in clean_df['hypoID'].unique():
    ex = clean_df.loc[clean_df['hypoID'] == hypo_id]
    agrees.append(len(Counter(ex.response)))
    if len(Counter(ex.response)) < 3:
        agree = ex.copy().iloc[0]
        agree.response = ex['response'].value_counts().idxmax()
        cum_df = cum_df.append(agree)

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.rcParams.update({'font.size': 15})
labels, counts = np.unique(agrees, return_counts=True)

plt.bar(labels, counts, align='center')
plt.gca().set_xticks(labels)
plt.xlabel('Number of Labels for Premise-Hypothesis Pair')
plt.ylabel('Count of Pairs')
plt.title('Agreement between Turkers for Premise-Hypo Pair')
plt.savefig('../graphs/Turker_Agreement.png', dpi = 200)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

plt.rcParams.update({'font.size': 15})
labels, counts = np.unique(cum_df.value_counts('premID'), return_counts=True)

plt.bar(labels, counts, align='center')
plt.gca().set_xticks(labels)
plt.xlabel('Remaining Hypothesis for a Premise')
plt.ylabel('Count of Premises')
plt.title('# Hypotheses per Premise Post No Majority Hypothesis Removal')
plt.savefig('../graphs/Premises_Left.png', dpi = 200)
plt.show()

# %%
cum_df
# Out:
#              Worker  hypoID  \
# 18   A2YOVBJ9EXAI8W    40.0
# 21   A2XYDJS33I2341    41.0
# 15   A3AK3UL0UCNVKE    43.0
# 90    ASVRLMDNQBUD9   248.0
# 93   A2EAJ7834XI2IT   249.0
# ..              ...     ...
# 60   A16P7DW4CB4JPM   175.0
# 108   AYZX9T7RBX3ZP   288.0
# 111  A2LR8E4O0FY66O   289.0
# 114  A2YOVBJ9EXAI8W   290.0
# 117   A5BVUW06ZQ6D3   291.0
#
#                                             hypothesis       mask-typ  \
# 18   The french painters that were represented incl...       gradient
# 21   The french painters that were represented incl...  content-words
# 15   The french painters that were represented incl...       original
# 90   The collection process does involve judgment c...       gradient
# 93   The collection process does not involve judgme...  content-words
# ..                                                 ...            ...
# 60    But there it is, she cannot speak at the moment.       original
# 108  They were hoping to have more services within ...       gradient
# 111  They were hoping to have more services within ...  content-words
# 114  They were able to keep all the services within...    data-slices
# 117  They were able to have more services within th...       original
#
#       premID                                            premise       response
# 18      34.0  French painters represented include Delacroix ...  contradiction
# 21      34.0  French painters represented include Delacroix ...        neutral
# 15      34.0  French painters represented include Delacroix ...     entailment
# 90     155.0  And the collection process involves judgment c...     entailment
# 93     155.0  And the collection process involves judgment c...        neutral
# ..       ...                                                ...            ...
# 60   12912.0  But there it is, she can tell you nothing." 11...        neutral
# 108  12990.0  It also will allow the organization to house i...        neutral
# 111  12990.0  It also will allow the organization to house i...     entailment
# 114  12990.0  It also will allow the organization to house i...     entailment
# 117  12990.0  It also will allow the organization to house i...     entailment
#
# [650 rows x 7 columns]

# %% [markdown]
# ### remove premises where not all hypothesizes had majority agreement

# %%
# remove by premise where there is incomplete data
missing_prems = []

for prem_id in cum_df['premID'].unique():
    if len(cum_df.loc[cum_df['premID'] == prem_id]) < 4:
        missing_prems.append(prem_id)
        
pure_df = cum_df[~cum_df['premID'].isin(missing_prems)]

# %%
pure_df['premID'].unique().shape
# Out:
# (112,)

# %%
pure_df
# Out:
#              Worker  hypoID  \
# 90    ASVRLMDNQBUD9   248.0
# 93   A2EAJ7834XI2IT   249.0
# 84    AYHK8DTZONHKC   250.0
# 87   A26NGLGGFTATVN   251.0
# 129  A1ZT30BGR3266K   324.0
# ..              ...     ...
# 60   A16P7DW4CB4JPM   175.0
# 108   AYZX9T7RBX3ZP   288.0
# 111  A2LR8E4O0FY66O   289.0
# 114  A2YOVBJ9EXAI8W   290.0
# 117   A5BVUW06ZQ6D3   291.0
#
#                                             hypothesis       mask-typ  \
# 90   The collection process does involve judgment c...       gradient
# 93   The collection process does not involve judgme...  content-words
# 84   The collection process does not always involve...    data-slices
# 87   The collection process does not involve judgme...       original
# 129  There will be no doubt that you will pay for w...       gradient
# ..                                                 ...            ...
# 60    But there it is, she cannot speak at the moment.       original
# 108  They were hoping to have more services within ...       gradient
# 111  They were hoping to have more services within ...  content-words
# 114  They were able to keep all the services within...    data-slices
# 117  They were able to have more services within th...       original
#
#       premID                                            premise       response
# 90     155.0  And the collection process involves judgment c...     entailment
# 93     155.0  And the collection process involves judgment c...        neutral
# 84     155.0  And the collection process involves judgment c...  contradiction
# 87     155.0  And the collection process involves judgment c...  contradiction
# 129    233.0  But you shall pay for it oh, yes, you shall pa...     entailment
# ..       ...                                                ...            ...
# 60   12912.0  But there it is, she can tell you nothing." 11...        neutral
# 108  12990.0  It also will allow the organization to house i...        neutral
# 111  12990.0  It also will allow the organization to house i...     entailment
# 114  12990.0  It also will allow the organization to house i...     entailment
# 117  12990.0  It also will allow the organization to house i...     entailment
#
# [448 rows x 7 columns]

# %%
reorg_cols = ['premID', 'premise', 'mask-typ', 'hypoID', 'hypothesis', 'response', 'Worker']
pure_df = pure_df.reindex(columns=reorg_cols)

# %%
pure_df
# Out:
#       premID                                            premise  \
# 90     155.0  And the collection process involves judgment c...
# 93     155.0  And the collection process involves judgment c...
# 84     155.0  And the collection process involves judgment c...
# 87     155.0  And the collection process involves judgment c...
# 129    233.0  But you shall pay for it oh, yes, you shall pa...
# ..       ...                                                ...
# 60   12912.0  But there it is, she can tell you nothing." 11...
# 108  12990.0  It also will allow the organization to house i...
# 111  12990.0  It also will allow the organization to house i...
# 114  12990.0  It also will allow the organization to house i...
# 117  12990.0  It also will allow the organization to house i...
#
#           mask-typ  hypoID                                         hypothesis  \
# 90        gradient   248.0  The collection process does involve judgment c...
# 93   content-words   249.0  The collection process does not involve judgme...
# 84     data-slices   250.0  The collection process does not always involve...
# 87        original   251.0  The collection process does not involve judgme...
# 129       gradient   324.0  There will be no doubt that you will pay for w...
# ..             ...     ...                                                ...
# 60        original   175.0   But there it is, she cannot speak at the moment.
# 108       gradient   288.0  They were hoping to have more services within ...
# 111  content-words   289.0  They were hoping to have more services within ...
# 114    data-slices   290.0  They were able to keep all the services within...
# 117       original   291.0  They were able to have more services within th...
#
#           response          Worker
# 90      entailment   ASVRLMDNQBUD9
# 93         neutral  A2EAJ7834XI2IT
# 84   contradiction   AYHK8DTZONHKC
# 87   contradiction  A26NGLGGFTATVN
# 129     entailment  A1ZT30BGR3266K
# ..             ...             ...
# 60         neutral  A16P7DW4CB4JPM
# 108        neutral   AYZX9T7RBX3ZP
# 111     entailment  A2LR8E4O0FY66O
# 114     entailment  A2YOVBJ9EXAI8W
# 117     entailment   A5BVUW06ZQ6D3
#
# [448 rows x 7 columns]

# %%
pure_df.to_csv('../results/pure_batch_results_3-3-21.csv')

# %% [markdown]
# ## Merging with Original Generation Data

# %%
m_df = pd.read_csv('../results/pure_batch_results_3-3-21.csv')
gen_df = pd.read_csv('../mturk/Pilot_Test_Master_92_3-3-21_labeled.csv')

# %%
gen_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  index  line-num  tokens-masked  \
# 0             0             0  59756      4096       gradient
# 1             1             1   6383      4096  content-words
# 2             2             2  42985      4096    data-slices
# 3             3             3  42985      4096       original
# 4             4             4   2352      4609       gradient
# ..          ...           ...    ...       ...            ...
# 751         751           751   4818      2554       original
# 752         752           752   3835      5628       gradient
# 753         753           753  26800      5628  content-words
# 754         754           754   5562      5628    data-slices
# 755         755           755   5562      5628       original
#
#                                                premise  \
# 0    He may have to send cables, or something like ...
# 1    He may have to send cables, or something like ...
# 2    He may have to send cables, or something like ...
# 3    He may have to send cables, or something like ...
# 4    Vigorously promote those legal services progra...
# ..                                                 ...
# 751  Second, mailers of some volume may be in posit...
# 752  they do not get referrals from the SEC and the...
# 753  they do not get referrals from the SEC and the...
# 754  they do not get referrals from the SEC and the...
# 755  they do not get referrals from the SEC and the...
#
#                                             hypothesis  \
# 0    There's no possibility that he will have to se...
# 1    There's no possibility that he will have to se...
# 2    There's no possibility that he will have to se...
# 3    There's no possibility that he will have to se...
# 4    The highest quality programs should be kept se...
# ..                                                 ...
# 751  All mailers of some volume can take advantage ...
# 752  The SEC and AICPA do not give referrals for em...
# 753  The SEC and AICPA do not give referrals for em...
# 754  The SEC and AICPA do not give referrals for em...
# 755  The SEC and AICPA do not give referrals for em...
#
#                                            mask-filled      flip-class  \
# 0    There's no possibility that he will not have t...    Certain-Flip
# 1    There's no guarantee that he will have to send...  Uncertain-Flip
# 2    There's a possibility that he will have to sen...    Certain-Flip
# 3    There's no possibility that he will have to se...    Certain-Same
# 4    The highest quality programs should be promote...  Uncertain-Same
# ..                                                 ...             ...
# 751  All mailers of some volume can take advantage ...    Certain-Same
# 752  The SEC and AICPA do not recommend them for em...  Uncertain-Same
# 753  The SEC and AICPA do not give referrals to peo...    Certain-Same
# 754  The SEC and AICPA do give them referrals for e...  Uncertain-Flip
# 755  The SEC and AICPA do not give referrals for em...    Certain-Same
#
#      weights     orig-label      new-label  orig-label-prob  same-label-prob  \
# 0       0.25  contradiction        neutral             1.00             0.08
# 1       0.75  contradiction        neutral             1.00             0.07
# 2       0.25  contradiction     entailment             1.00             0.00
# 3       0.25  contradiction  contradiction             1.00             1.00
# 4       0.75  contradiction  contradiction             1.00             0.61
# ..       ...            ...            ...              ...              ...
# 751     0.75  contradiction  contradiction             0.59             0.59
# 752     0.75        neutral        neutral             0.99             0.79
# 753     0.25        neutral        neutral             0.99             0.97
# 754     0.75        neutral  contradiction             0.99             0.26
# 755     0.75        neutral        neutral             0.99             0.99
#
#      new-label-prob  label-changed  same-label-prob-diff
# 0              0.80           True                  0.92
# 1              0.68           True                  0.93
# 2              0.99           True                  1.00
# 3              1.00          False                  0.00
# 4              0.61          False                  0.39
# ..              ...            ...                   ...
# 751            0.59          False                  0.00
# 752            0.79          False                  0.20
# 753            0.97          False                  0.02
# 754            0.74           True                  0.73
# 755            0.99          False                  0.00
#
# [756 rows x 17 columns]

# %%
m_df
# Out:
#      Unnamed: 0   premID                                            premise  \
# 0            90    155.0  And the collection process involves judgment c...
# 1            93    155.0  And the collection process involves judgment c...
# 2            84    155.0  And the collection process involves judgment c...
# 3            87    155.0  And the collection process involves judgment c...
# 4           129    233.0  But you shall pay for it oh, yes, you shall pa...
# ..          ...      ...                                                ...
# 443          60  12912.0  But there it is, she can tell you nothing." 11...
# 444         108  12990.0  It also will allow the organization to house i...
# 445         111  12990.0  It also will allow the organization to house i...
# 446         114  12990.0  It also will allow the organization to house i...
# 447         117  12990.0  It also will allow the organization to house i...
#
#           mask-typ  hypoID                                         hypothesis  \
# 0         gradient   248.0  The collection process does involve judgment c...
# 1    content-words   249.0  The collection process does not involve judgme...
# 2      data-slices   250.0  The collection process does not always involve...
# 3         original   251.0  The collection process does not involve judgme...
# 4         gradient   324.0  There will be no doubt that you will pay for w...
# ..             ...     ...                                                ...
# 443       original   175.0   But there it is, she cannot speak at the moment.
# 444       gradient   288.0  They were hoping to have more services within ...
# 445  content-words   289.0  They were hoping to have more services within ...
# 446    data-slices   290.0  They were able to keep all the services within...
# 447       original   291.0  They were able to have more services within th...
#
#           response          Worker
# 0       entailment   ASVRLMDNQBUD9
# 1          neutral  A2EAJ7834XI2IT
# 2    contradiction   AYHK8DTZONHKC
# 3    contradiction  A26NGLGGFTATVN
# 4       entailment  A1ZT30BGR3266K
# ..             ...             ...
# 443        neutral  A16P7DW4CB4JPM
# 444        neutral   AYZX9T7RBX3ZP
# 445     entailment  A2LR8E4O0FY66O
# 446     entailment  A2YOVBJ9EXAI8W
# 447     entailment   A5BVUW06ZQ6D3
#
# [448 rows x 8 columns]

# %%
big_df = pd.merge(m_df, gen_df, left_on = 'hypoID', right_on = 'Unnamed: 0')
big_df
# Out:
#      Unnamed: 0_x   premID                                          premise_x  \
# 0              90    155.0  And the collection process involves judgment c...
# 1              93    155.0  And the collection process involves judgment c...
# 2              84    155.0  And the collection process involves judgment c...
# 3              87    155.0  And the collection process involves judgment c...
# 4             129    233.0  But you shall pay for it oh, yes, you shall pa...
# ..            ...      ...                                                ...
# 443            60  12912.0  But there it is, she can tell you nothing." 11...
# 444           108  12990.0  It also will allow the organization to house i...
# 445           111  12990.0  It also will allow the organization to house i...
# 446           114  12990.0  It also will allow the organization to house i...
# 447           117  12990.0  It also will allow the organization to house i...
#
#           mask-typ  hypoID                                       hypothesis_x  \
# 0         gradient   248.0  The collection process does involve judgment c...
# 1    content-words   249.0  The collection process does not involve judgme...
# 2      data-slices   250.0  The collection process does not always involve...
# 3         original   251.0  The collection process does not involve judgme...
# 4         gradient   324.0  There will be no doubt that you will pay for w...
# ..             ...     ...                                                ...
# 443       original   175.0   But there it is, she cannot speak at the moment.
# 444       gradient   288.0  They were hoping to have more services within ...
# 445  content-words   289.0  They were hoping to have more services within ...
# 446    data-slices   290.0  They were able to keep all the services within...
# 447       original   291.0  They were able to have more services within th...
#
#           response          Worker  Unnamed: 0_y  Unnamed: 0.1  ...  \
# 0       entailment   ASVRLMDNQBUD9           248           248  ...
# 1          neutral  A2EAJ7834XI2IT           249           249  ...
# 2    contradiction   AYHK8DTZONHKC           250           250  ...
# 3    contradiction  A26NGLGGFTATVN           251           251  ...
# 4       entailment  A1ZT30BGR3266K           324           324  ...
# ..             ...             ...           ...           ...  ...
# 443        neutral  A16P7DW4CB4JPM           175           175  ...
# 444        neutral   AYZX9T7RBX3ZP           288           288  ...
# 445     entailment  A2LR8E4O0FY66O           289           289  ...
# 446     entailment  A2YOVBJ9EXAI8W           290           290  ...
# 447     entailment   A5BVUW06ZQ6D3           291           291  ...
#
#                                            mask-filled      flip-class  \
# 0    The collection process does involve judgment c...    Certain-Flip
# 1    The collection process does not involve judgme...  Uncertain-Same
# 2    The collection process does not always involve...  Uncertain-Flip
# 3    The collection process does not involve judgme...    Certain-Same
# 4    There will be no doubt that you will pay for w...  Uncertain-Flip
# ..                                                 ...             ...
# 443   But there it is, she cannot speak at the moment.    Certain-Same
# 444  They were hoping to have more services within ...    Certain-Flip
# 445  They were hoping to have more services within ...    Certain-Flip
# 446  They were able to keep all the services within...  Uncertain-Same
# 447  They were able to have more services within th...    Certain-Same
#
#     weights     orig-label      new-label orig-label-prob same-label-prob  \
# 0      0.25  contradiction     entailment            1.00            0.00
# 1      0.75  contradiction  contradiction            1.00            0.50
# 2      0.75  contradiction        neutral            1.00            0.31
# 3      0.75  contradiction  contradiction            1.00            1.00
# 4      0.75  contradiction     entailment            1.00            0.00
# ..      ...            ...            ...             ...             ...
# 443    0.75        neutral        neutral            0.85            0.85
# 444    0.25     entailment        neutral            0.97            0.01
# 445    0.25     entailment        neutral            0.97            0.01
# 446    0.75     entailment     entailment            0.97            0.66
# 447    0.75     entailment     entailment            0.97            0.97
#
#      new-label-prob label-changed same-label-prob-diff
# 0              0.95          True                 1.00
# 1              0.50         False                 0.50
# 2              0.68          True                 0.69
# 3              1.00         False                 0.00
# 4              0.68          True                 1.00
# ..              ...           ...                  ...
# 443            0.85         False                 0.00
# 444            0.99          True                 0.96
# 445            0.99          True                 0.96
# 446            0.66         False                 0.31
# 447            0.97         False                 0.00
#
# [448 rows x 25 columns]

# %% [markdown]
# ## Remove annotators that are noisy (don't have correct labels on original)

# %%
big_df['model_wrong'] = big_df.response != big_df['new-label']

# %%
big_df['Worker'].unique()
# Out:
# array(['ASVRLMDNQBUD9', 'A2EAJ7834XI2IT', 'AYHK8DTZONHKC',
#        'A26NGLGGFTATVN', 'A1ZT30BGR3266K', 'A3V2XCDF45VN9X',
#        'A37STRL9Z7ZDSD', 'A2SD7GN80U31GW', 'A31681CCEVDIH3',
#        'ACJ6NSCIWMUZI', 'A3I9XLIHPPWPN1', 'A2D62KZUMKIA8K',
#        'A9ZBEA4T2FNZ3', 'AFU00NU09CFXE', 'A17LF7GCAFYMSL',
#        'A2XJH3WC02RMXQ', 'ACJ12KIXGZZFH', 'A147F5PJTHOB8A',
#        'AQORJW4W8U9YU', 'A3CE0SWITZK3UD', 'A1DS5O8MSI3ZH0',
#        'AKQAI78JTXXC9', 'A1F1BIPJR11LSR', 'A2PDEHYI2M81EC',
#        'A2NHFSO7GMM8QR', 'A1PBFDQR599N3K', 'AV22FQTJNBUZT',
#        'A25KM5DM1Z09ZN', 'A1G452MFAS690B', 'A1PAY3X73PQ16S',
#        'A3TJ2AMFKJGXL4', 'A34CPKFZXBX1PO', 'AC0BP4IGV99MS',
#        'A3RYI5HXC2MJLN', 'A29AKJXQ248KNK', 'A3AK3UL0UCNVKE',
#        'A2YOVBJ9EXAI8W', 'A2XYDJS33I2341', 'A2LR8E4O0FY66O',
#        'A5BVUW06ZQ6D3', 'AYZX9T7RBX3ZP', 'A3SLISG1IED7TZ',
#        'A1D9ZWU1M46SAF', 'A2T11H7YI7QPGD', 'A9HQ3E0F2AGVO',
#        'ATKLWAX72HM7A', 'A365SN61J4UNGR', 'AAPRQ5DHT6X2R',
#        'A8WLCSZLNZ8BL', 'AIY8KHG5LEXNY', 'A12FTSX85NQ8N9',
#        'A2EZVULYVJOPNO', 'A1PZIN8H1VI6SY', 'AVIEE6LDH0BT5',
#        'AZ8JL3QNIPY4U', 'A2JP9IKRHNLRPI', 'A28LMUIZO84GAX',
#        'A3UP4PP3ZF1J39', 'A2IG18D6M0GNUZ', 'AWAW665TQQP2F',
#        'A382SL9ROIY1P6', 'A273PAYHIAJHO7', 'A746183X8258H',
#        'A1CX45M5UVAM9R', 'A16P7DW4CB4JPM', 'A3KU8DC7HJOGCM',
#        'A1PTH9KTRO06EG', 'A2CS8ESKDX6EBA', 'A3TUMZ954ORSUC',
#        'A24RGLS3BRZ60J'], dtype=object)

# %%
bad_workers = []
for worker in big_df['Worker'].unique():
    cut = big_df.loc[big_df['Worker'] == worker]
    cut = cut.loc[cut['mask-typ'] == 'original']
    if sum(cut['model_wrong']) > 0:
        bad_workers.append(worker)

print(bad_workers)
# Out:
# ['ASVRLMDNQBUD9', 'A2EAJ7834XI2IT', 'AYHK8DTZONHKC', 'A1ZT30BGR3266K', 'A2SD7GN80U31GW', 'ACJ6NSCIWMUZI', 'A9ZBEA4T2FNZ3', 'AFU00NU09CFXE', 'A17LF7GCAFYMSL', 'A3CE0SWITZK3UD', 'AKQAI78JTXXC9', 'A1F1BIPJR11LSR', 'A1PBFDQR599N3K', 'AV22FQTJNBUZT', 'A1G452MFAS690B', 'A1PAY3X73PQ16S', 'A3TJ2AMFKJGXL4', 'AC0BP4IGV99MS', 'A3RYI5HXC2MJLN', 'A2YOVBJ9EXAI8W', 'A2XYDJS33I2341', 'AYZX9T7RBX3ZP', 'A3SLISG1IED7TZ', 'A1D9ZWU1M46SAF', 'A12FTSX85NQ8N9', 'A1PZIN8H1VI6SY', 'A1PTH9KTRO06EG', 'A2CS8ESKDX6EBA', 'A3TUMZ954ORSUC']

# %%
big_df.groupby(['mask-typ', 'flip-class']).agg({'model_wrong': ['mean', 'count', 'sum']})
# Out:
#                              model_wrong
#                                     mean count sum
# mask-typ      flip-class
# content-words Certain-Flip      0.391304    23   9
#               Certain-Same      0.300000    20   6
#               Uncertain-Flip    0.583333    36  21
#               Uncertain-Same    0.606061    33  20
# data-slices   Certain-Flip      0.250000    20   5
#               Certain-Same      0.264706    34   9
#               Uncertain-Flip    0.586207    29  17
#               Uncertain-Same    0.517241    29  15
# gradient      Certain-Flip      0.434783    23  10
#               Certain-Same      0.368421    19   7
#               Uncertain-Flip    0.463415    41  19
#               Uncertain-Same    0.379310    29  11
# original      Certain-Same      0.276786   112  31

# %% [markdown]
# ## Trying on Less Pure Splits of the Data

# %%
big_bad_df = pd.merge(cum_df, gen_df, left_on = 'hypoID', right_on = 'Unnamed: 0')

# %%
big_bad_df['model_wrong'] = big_bad_df.response != big_bad_df['new-label']
big_bad_df.groupby(['mask-typ', 'flip-class']).agg({'model_wrong': ['mean', 'count', 'sum']}).T
# Out:
# mask-typ          content-words                                             \
# flip-class         Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model_wrong mean       0.366667     0.354839       0.509091        0.55814
#             count     30.000000    31.000000      55.000000       43.00000
#             sum       11.000000    11.000000      28.000000       24.00000
#
# mask-typ           data-slices                                             \
# flip-class        Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model_wrong mean      0.294118     0.319149       0.560976        0.44186
#             count    34.000000    47.000000      41.000000       43.00000
#             sum      10.000000    15.000000      23.000000       19.00000
#
# mask-typ              gradient                                             \
# flip-class        Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model_wrong mean      0.407407         0.28       0.484375       0.454545
#             count    27.000000        25.00      64.000000      44.000000
#             sum      11.000000         7.00      31.000000      20.000000
#
# mask-typ              original
# flip-class        Certain-Same
# model_wrong mean      0.277108
#             count   166.000000
#             sum      46.000000

# %%
big_horrible_df = pd.merge(s_df, gen_df, left_on = 'hypoID', right_on = 'Unnamed: 0')

# %%
big_horrible_df['model_wrong'] = big_horrible_df.response != big_horrible_df['new-label']
big_horrible_df.groupby(['mask-typ', 'flip-class']).agg({'model_wrong': ['mean', 'count', 'sum']}).T
# Out:
# mask-typ          content-words                                             \
# flip-class         Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model_wrong mean       0.435185     0.441176       0.557377       0.584906
#             count    108.000000   102.000000     183.000000     159.000000
#             sum       47.000000    45.000000     102.000000      93.000000
#
# mask-typ           data-slices                                             \
# flip-class        Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model_wrong mean      0.384615     0.379085       0.533333       0.530612
#             count   117.000000   153.000000     135.000000     147.000000
#             sum      45.000000    58.000000      72.000000      78.000000
#
# mask-typ              gradient                                             \
# flip-class        Certain-Flip Certain-Same Uncertain-Flip Uncertain-Same
# model_wrong mean      0.448276     0.440476       0.555556       0.532051
#             count    87.000000    84.000000     225.000000     156.000000
#             sum      39.000000    37.000000     125.000000      83.000000
#
# mask-typ              original
# flip-class        Certain-Same
# model_wrong mean      0.382246
#             count   552.000000
#             sum     211.000000
